# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 768

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=a87bfa8e1555a2fde65f9c3126de0bab

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yar-sale
# Processing Record 2 of Set 1 | lebu
# Processing Record 3 of Set 1 | namtsy
# Processing Record 4 of Set 1 | kashary
# Processing Record 5 of Set 1 | progreso
# Processing Record 6 of Set 1 | biak
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | talaya
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | kodiak
# Processing Record 12 of Set 1 | boa vista
# Processing Record 13 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 1 | ondorhaan
# City not found. Skipping...
# Processing Record 15 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 16 of Set 1 | esperance
# Processing Record 17 of Set 1 | longyearbyen
# Processing Record 18 of Set 1 | socorro
# Processing Record 19 of Set 1 | hofn
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | butaritari
# Processing Record 22 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 1 | noumea
# Processing Record 24 of Set 1 | huron
# Processing Record 25 of Set 1 | grand-santi
# Processing Record 26 of Set 1 | clyde river
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | malakal
# Processing Record 29 of Set 1 | coihaique
# Processing Record 30 of Set 1 | hithadhoo
# Processing Record 31 of Set 1 | kupang
# Processing Record 32 of Set 1 | chokurdakh
# Processing Record 33 of Set 1 | pacific grove
# Processing Record 34 of Set 1 | east london
# Processing Record 35 of Set 1 | bluff
# Processing Record 36 of Set 1 | new norfolk
# Processing Record 37 of Set 1 | cape coast
# Processing Record 38 of Set 1 | puerto ayora
# Processing Record 39 of Set 1 | humaita
# Processing Record 40 of Set 1 | sembe
# Processing Record 41 of Set 1 | saldanha
# Processing Record 42 of Set 1 | mataura
# Processing Record 43 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | jalu
# Processing Record 46 of Set 1 | canals
# Processing Record 47 of Set 1 | port elizabeth
# Processing Record 48 of Set 1 | prince rupert
# Processing Record 49 of Set 1 | khatanga
# Processing Record 50 of Set 1 | ketchikan
# Processing Record 1 of Set 2 | saskylakh
# Processing Record 2 of Set 2 | upernavik
# Processing Record 3 of Set 2 | kaitangata
# Processing Record 4 of Set 2 | moguer
# Processing Record 5 of Set 2 | busselton
# Processing Record 6 of Set 2 | hobart
# Processing Record 7 of Set 2 | talnakh
# Processing Record 8 of Set 2 | college
# Processing Record 9 of Set 2 | hilo
# Processing Record 10 of Set 2 | kurtamysh
# Processing Record 11 of Set 2 | ancud
# Processing Record 12 of Set 2 | severo-kurilsk
# Processing Record 13 of Set 2 | pevek
# Processing Record 14 of Set 2 | isla vista
# Processing Record 15 of Set 2 | belyy yar
# Processing Record 16 of Set 2 | barrow
# Processing Record 17 of Set 2 | manzhouli
# Processing Record 18 of Set 2 | sao joao da barra
# Processing Record 19 of Set 2 | cumberland
# Processing Record 20 of Set 2 | mogadishu
# Processing Record 21 of Set 2 | arraial do cabo
# Processing Record 22 of Set 2 | yabrud
# Processing Record 23 of Set 2 | vaini
# Processing Record 24 of Set 2 | cape town
# Processing Record 25 of Set 2 | stornoway
# Processing Record 26 of Set 2 | kapaa
# Processing Record 27 of Set 2 | batsfjord
# Processing Record 28 of Set 2 | saint george
# Processing Record 29 of Set 2 | vila velha
# Processing Record 30 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 31 of Set 2 | beringovskiy
# Processing Record 32 of Set 2 | yellowknife
# Processing Record 33 of Set 2 | mponela
# Processing Record 34 of Set 2 | henties bay
# Processing Record 35 of Set 2 | mar del plata
# Processing Record 36 of Set 2 | pochutla
# Processing Record 37 of Set 2 | vila franca do campo
# Processing Record 38 of Set 2 | charagua
# Processing Record 39 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 2 | thompson
# Processing Record 41 of Set 2 | campestre
# Processing Record 42 of Set 2 | vostok
# Processing Record 43 of Set 2 | saint-philippe
# Processing Record 44 of Set 2 | moron
# Processing Record 45 of Set 2 | raichur
# Processing Record 46 of Set 2 | lompoc
# Processing Record 47 of Set 2 | sioux lookout
# Processing Record 48 of Set 2 | mbeya
# Processing Record 49 of Set 2 | magadan
# Processing Record 50 of Set 2 | torbay
# Processing Record 1 of Set 3 | avera
# Processing Record 2 of Set 3 | baruun-urt
# Processing Record 3 of Set 3 | norman wells
# Processing Record 4 of Set 3 | uyuni
# Processing Record 5 of Set 3 | port alfred
# Processing Record 6 of Set 3 | bredasdorp
# Processing Record 7 of Set 3 | silyanah
# City not found. Skipping...
# Processing Record 8 of Set 3 | hasaki
# Processing Record 9 of Set 3 | taber
# Processing Record 10 of Set 3 | deputatskiy
# Processing Record 11 of Set 3 | dawson creek
# Processing Record 12 of Set 3 | waverley
# Processing Record 13 of Set 3 | hervey bay
# Processing Record 14 of Set 3 | mount gambier
# Processing Record 15 of Set 3 | aklavik
# Processing Record 16 of Set 3 | kushmurun
# Processing Record 17 of Set 3 | ballina
# Processing Record 18 of Set 3 | nuuk
# Processing Record 19 of Set 3 | kenai
# Processing Record 20 of Set 3 | atambua
# Processing Record 21 of Set 3 | airai
# Processing Record 22 of Set 3 | lorengau
# Processing Record 23 of Set 3 | miandrivazo
# Processing Record 24 of Set 3 | morondava
# Processing Record 25 of Set 3 | forbes
# Processing Record 26 of Set 3 | souillac
# Processing Record 27 of Set 3 | nikolskoye
# Processing Record 28 of Set 3 | saint-georges
# Processing Record 29 of Set 3 | saint anthony
# Processing Record 30 of Set 3 | sinazongwe
# Processing Record 31 of Set 3 | victoria
# Processing Record 32 of Set 3 | edeia
# Processing Record 33 of Set 3 | farah
# Processing Record 34 of Set 3 | makakilo city
# Processing Record 35 of Set 3 | cidreira
# Processing Record 36 of Set 3 | kavieng
# Processing Record 37 of Set 3 | kailua
# Processing Record 38 of Set 3 | aksarka
# Processing Record 39 of Set 3 | cabo san lucas
# Processing Record 40 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 3 | tuktoyaktuk
# Processing Record 42 of Set 3 | faanui
# Processing Record 43 of Set 3 | castro
# Processing Record 44 of Set 3 | swan hill
# Processing Record 45 of Set 3 | sarahan
# Processing Record 46 of Set 3 | qaanaaq
# Processing Record 47 of Set 3 | lagos
# Processing Record 48 of Set 3 | ruteng
# Processing Record 49 of Set 3 | zilair
# Processing Record 50 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 4 | provideniya
# Processing Record 2 of Set 4 | mahajanga
# Processing Record 3 of Set 4 | bahia blanca
# Processing Record 4 of Set 4 | shaunavon
# Processing Record 5 of Set 4 | ouesso
# Processing Record 6 of Set 4 | hermanus
# Processing Record 7 of Set 4 | bejar
# Processing Record 8 of Set 4 | yozgat
# Processing Record 9 of Set 4 | jucas
# Processing Record 10 of Set 4 | taltal
# Processing Record 11 of Set 4 | port hedland
# Processing Record 12 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 13 of Set 4 | shirokiy
# Processing Record 14 of Set 4 | shatrovo
# Processing Record 15 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 4 | kushikino
# Processing Record 17 of Set 4 | zhuanghe
# Processing Record 18 of Set 4 | canby
# Processing Record 19 of Set 4 | nanortalik
# Processing Record 20 of Set 4 | dingle
# Processing Record 21 of Set 4 | am timan
# Processing Record 22 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 4 | lavrentiya
# Processing Record 24 of Set 4 | eyl
# Processing Record 25 of Set 4 | suez
# Processing Record 26 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 27 of Set 4 | avarua
# Processing Record 28 of Set 4 | vemalwada
# Processing Record 29 of Set 4 | port-gentil
# Processing Record 30 of Set 4 | san jeronimo
# Processing Record 31 of Set 4 | payo
# Processing Record 32 of Set 4 | gao
# Processing Record 33 of Set 4 | ostra
# Processing Record 34 of Set 4 | tiznit
# Processing Record 35 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 36 of Set 4 | nouadhibou
# Processing Record 37 of Set 4 | maceio
# Processing Record 38 of Set 4 | ribeira grande
# Processing Record 39 of Set 4 | bengkulu
# Processing Record 40 of Set 4 | ponta do sol
# Processing Record 41 of Set 4 | matagami
# Processing Record 42 of Set 4 | of
# City not found. Skipping...
# Processing Record 43 of Set 4 | haines junction
# Processing Record 44 of Set 4 | kapoeta
# Processing Record 45 of Set 4 | archidona
# Processing Record 46 of Set 4 | papara
# Processing Record 47 of Set 4 | oranjemund
# Processing Record 48 of Set 4 | tabory
# Processing Record 49 of Set 4 | carnarvon
# Processing Record 50 of Set 4 | georgetown
# Processing Record 1 of Set 5 | ilo
# Processing Record 2 of Set 5 | sobolevo
# Processing Record 3 of Set 5 | aripuana
# Processing Record 4 of Set 5 | srednekolymsk
# Processing Record 5 of Set 5 | chaihe
# Processing Record 6 of Set 5 | chapais
# Processing Record 7 of Set 5 | necochea
# Processing Record 8 of Set 5 | yanchukan
# City not found. Skipping...
# Processing Record 9 of Set 5 | yazykovo
# Processing Record 10 of Set 5 | zambezi
# Processing Record 11 of Set 5 | skibbereen
# Processing Record 12 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 5 | bardsir
# Processing Record 14 of Set 5 | rawah
# Processing Record 15 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 16 of Set 5 | angicos
# Processing Record 17 of Set 5 | lambayeque
# Processing Record 18 of Set 5 | isangel
# Processing Record 19 of Set 5 | cherskiy
# Processing Record 20 of Set 5 | sao filipe
# Processing Record 21 of Set 5 | urumqi
# Processing Record 22 of Set 5 | diamantino
# Processing Record 23 of Set 5 | coos bay
# Processing Record 24 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 5 | harsud
# Processing Record 26 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 27 of Set 5 | kristiansund
# Processing Record 28 of Set 5 | boca do acre
# Processing Record 29 of Set 5 | komsomolskiy
# Processing Record 30 of Set 5 | viedma
# Processing Record 31 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 5 | grindavik
# Processing Record 33 of Set 5 | port moresby
# Processing Record 34 of Set 5 | athabasca
# Processing Record 35 of Set 5 | tiarei
# Processing Record 36 of Set 5 | muzhi
# Processing Record 37 of Set 5 | shubarshi
# Processing Record 38 of Set 5 | faya
# Processing Record 39 of Set 5 | lasa
# Processing Record 40 of Set 5 | leku
# Processing Record 41 of Set 5 | gazli
# Processing Record 42 of Set 5 | atar
# Processing Record 43 of Set 5 | bull savanna
# Processing Record 44 of Set 5 | coquimbo
# Processing Record 45 of Set 5 | karratha
# Processing Record 46 of Set 5 | san luis
# Processing Record 47 of Set 5 | victoria point
# Processing Record 48 of Set 5 | korla
# Processing Record 49 of Set 5 | tasiilaq
# Processing Record 50 of Set 5 | port lincoln
# Processing Record 1 of Set 6 | teya
# Processing Record 2 of Set 6 | mahebourg
# Processing Record 3 of Set 6 | kayes
# Processing Record 4 of Set 6 | jalna
# Processing Record 5 of Set 6 | omsukchan
# Processing Record 6 of Set 6 | namibe
# Processing Record 7 of Set 6 | malkangiri
# Processing Record 8 of Set 6 | kampot
# Processing Record 9 of Set 6 | te anau
# Processing Record 10 of Set 6 | virginia beach
# Processing Record 11 of Set 6 | sambava
# Processing Record 12 of Set 6 | gibara
# Processing Record 13 of Set 6 | sisimiut
# Processing Record 14 of Set 6 | flin flon
# Processing Record 15 of Set 6 | lauria
# Processing Record 16 of Set 6 | port hardy
# Processing Record 17 of Set 6 | alyangula
# Processing Record 18 of Set 6 | biltine
# Processing Record 19 of Set 6 | san patricio
# Processing Record 20 of Set 6 | bethel
# Processing Record 21 of Set 6 | tecoanapa
# Processing Record 22 of Set 6 | sakata
# Processing Record 23 of Set 6 | almaznyy
# Processing Record 24 of Set 6 | hirara
# Processing Record 25 of Set 6 | tubuala
# Processing Record 26 of Set 6 | ojinaga
# Processing Record 27 of Set 6 | sorland
# Processing Record 28 of Set 6 | porangatu
# Processing Record 29 of Set 6 | rock sound
# Processing Record 30 of Set 6 | abu jubayhah
# City not found. Skipping...
# Processing Record 31 of Set 6 | rawlins
# Processing Record 32 of Set 6 | ranfurly
# Processing Record 33 of Set 6 | buenos aires
# Processing Record 34 of Set 6 | simplicio mendes
# Processing Record 35 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 36 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 37 of Set 6 | erenhot
# Processing Record 38 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 39 of Set 6 | molina
# Processing Record 40 of Set 6 | cazaje
# City not found. Skipping...
# Processing Record 41 of Set 6 | saint-augustin
# Processing Record 42 of Set 6 | warrnambool
# Processing Record 43 of Set 6 | shingu
# Processing Record 44 of Set 6 | klaksvik
# Processing Record 45 of Set 6 | japura
# Processing Record 46 of Set 6 | shenjiamen
# Processing Record 47 of Set 6 | katima mulilo
# Processing Record 48 of Set 6 | oda
# Processing Record 49 of Set 6 | tera
# Processing Record 50 of Set 6 | alofi
# Processing Record 1 of Set 7 | el alto
# Processing Record 2 of Set 7 | bilma
# Processing Record 3 of Set 7 | iqaluit
# Processing Record 4 of Set 7 | kijang
# Processing Record 5 of Set 7 | diego de almagro
# Processing Record 6 of Set 7 | moratuwa
# Processing Record 7 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 7 | kruisfontein
# Processing Record 10 of Set 7 | batagay
# Processing Record 11 of Set 7 | cockburn town
# Processing Record 12 of Set 7 | hoi an
# Processing Record 13 of Set 7 | waddan
# Processing Record 14 of Set 7 | anadyr
# Processing Record 15 of Set 7 | teluk intan
# Processing Record 16 of Set 7 | honiara
# Processing Record 17 of Set 7 | nioro
# Processing Record 18 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 19 of Set 7 | antofagasta
# Processing Record 20 of Set 7 | valparaiso
# Processing Record 21 of Set 7 | san ignacio
# Processing Record 22 of Set 7 | balakovo
# Processing Record 23 of Set 7 | neryungri
# Processing Record 24 of Set 7 | inyonga
# Processing Record 25 of Set 7 | road town
# Processing Record 26 of Set 7 | huarmey
# Processing Record 27 of Set 7 | bandarbeyla
# Processing Record 28 of Set 7 | price
# Processing Record 29 of Set 7 | gat
# Processing Record 30 of Set 7 | agadir
# Processing Record 31 of Set 7 | spencer
# Processing Record 32 of Set 7 | baltiysk
# Processing Record 33 of Set 7 | namatanai
# Processing Record 34 of Set 7 | los llanos de aridane
# Processing Record 35 of Set 7 | berlevag
# Processing Record 36 of Set 7 | quanzhou
# Processing Record 37 of Set 7 | northam
# Processing Record 38 of Set 7 | sinnamary
# Processing Record 39 of Set 7 | kushiro
# Processing Record 40 of Set 7 | san juan
# Processing Record 41 of Set 7 | dikson
# Processing Record 42 of Set 7 | cockburn harbour
# City not found. Skipping...
# Processing Record 43 of Set 7 | marshfield
# Processing Record 44 of Set 7 | katsuura
# Processing Record 45 of Set 7 | meulaboh
# Processing Record 46 of Set 7 | acapulco
# Processing Record 47 of Set 7 | micheweni
# Processing Record 48 of Set 7 | morant bay
# Processing Record 49 of Set 7 | dudinka
# Processing Record 50 of Set 7 | paita
# Processing Record 1 of Set 8 | iskateley
# Processing Record 2 of Set 8 | aswan
# Processing Record 3 of Set 8 | kysyl-syr
# Processing Record 4 of Set 8 | zavetnoye
# Processing Record 5 of Set 8 | toledo
# Processing Record 6 of Set 8 | evensk
# Processing Record 7 of Set 8 | arlit
# Processing Record 8 of Set 8 | luderitz
# Processing Record 9 of Set 8 | terrasini
# Processing Record 10 of Set 8 | luau
# Processing Record 11 of Set 8 | montmagny
# Processing Record 12 of Set 8 | cap malheureux
# Processing Record 13 of Set 8 | ous
# Processing Record 14 of Set 8 | shangzhi
# Processing Record 15 of Set 8 | marapanim
# Processing Record 16 of Set 8 | hamilton
# Processing Record 17 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 8 | mecca
# Processing Record 19 of Set 8 | worthington
# Processing Record 20 of Set 8 | labuhan
# Processing Record 21 of Set 8 | carnot
# Processing Record 22 of Set 8 | pasighat
# Processing Record 23 of Set 8 | tulun
# Processing Record 24 of Set 8 | gizo
# Processing Record 25 of Set 8 | portland
# Processing Record 26 of Set 8 | broken hill
# Processing Record 27 of Set 8 | whitianga
# Processing Record 28 of Set 8 | hattiesburg
# Processing Record 29 of Set 8 | tupik
# Processing Record 30 of Set 8 | jeremoabo
# Processing Record 31 of Set 8 | ust-tsilma
# Processing Record 32 of Set 8 | santa maria do para
# Processing Record 33 of Set 8 | tiksi
# Processing Record 34 of Set 8 | provost
# Processing Record 35 of Set 8 | sao pedro do sul
# Processing Record 36 of Set 8 | asau
# Processing Record 37 of Set 8 | coamo
# Processing Record 38 of Set 8 | le port
# Processing Record 39 of Set 8 | beipiao
# Processing Record 40 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 41 of Set 8 | sheridan
# Processing Record 42 of Set 8 | arica
# Processing Record 43 of Set 8 | lafayette
# Processing Record 44 of Set 8 | maumere
# Processing Record 45 of Set 8 | chuy
# Processing Record 46 of Set 8 | plettenberg bay
# Processing Record 47 of Set 8 | yulara
# Processing Record 48 of Set 8 | verkhnevilyuysk
# Processing Record 49 of Set 8 | saint stephen
# Processing Record 50 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 1 of Set 9 | san rafael
# Processing Record 2 of Set 9 | ziyang
# Processing Record 3 of Set 9 | unity
# Processing Record 4 of Set 9 | iranshahr
# Processing Record 5 of Set 9 | harur
# Processing Record 6 of Set 9 | wittstock
# Processing Record 7 of Set 9 | sulangan
# Processing Record 8 of Set 9 | limoges
# Processing Record 9 of Set 9 | key west
# Processing Record 10 of Set 9 | outjo
# Processing Record 11 of Set 9 | cap-aux-meules
# Processing Record 12 of Set 9 | elk river
# Processing Record 13 of Set 9 | princes town
# Processing Record 14 of Set 9 | vardo
# Processing Record 15 of Set 9 | merauke
# Processing Record 16 of Set 9 | nantucket
# Processing Record 17 of Set 9 | ginir
# Processing Record 18 of Set 9 | umea
# Processing Record 19 of Set 9 | saint-pierre
# Processing Record 20 of Set 9 | yerofey pavlovich
# Processing Record 21 of Set 9 | kitimat
# Processing Record 22 of Set 9 | porto santo
# Processing Record 23 of Set 9 | awash
# Processing Record 24 of Set 9 | taksimo
# Processing Record 25 of Set 9 | salalah
# Processing Record 26 of Set 9 | warri
# Processing Record 27 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 28 of Set 9 | muisne
# Processing Record 29 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 9 | temir
# Processing Record 31 of Set 9 | neiafu
# Processing Record 32 of Set 9 | betafo
# Processing Record 33 of Set 9 | kahului
# Processing Record 34 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 35 of Set 9 | leningradskiy
# Processing Record 36 of Set 9 | waipawa
# Processing Record 37 of Set 9 | korop
# Processing Record 38 of Set 9 | sept-iles
# Processing Record 39 of Set 9 | bireun
# Processing Record 40 of Set 9 | noda
# Processing Record 41 of Set 9 | port macquarie
# Processing Record 42 of Set 9 | yilan
# Processing Record 43 of Set 9 | shchigry
# Processing Record 44 of Set 9 | tonantins
# Processing Record 45 of Set 9 | suclayin
# Processing Record 46 of Set 9 | sorong
# Processing Record 47 of Set 9 | makinsk
# Processing Record 48 of Set 9 | mutsamudu
# City not found. Skipping...
# Processing Record 49 of Set 9 | carutapera
# Processing Record 50 of Set 9 | alcaniz
# Processing Record 1 of Set 10 | bonnyville
# Processing Record 2 of Set 10 | atasu
# Processing Record 3 of Set 10 | lagoa
# Processing Record 4 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 5 of Set 10 | namie
# Processing Record 6 of Set 10 | bowen
# Processing Record 7 of Set 10 | saint-joseph
# Processing Record 8 of Set 10 | christchurch
# Processing Record 9 of Set 10 | havre-saint-pierre
# Processing Record 10 of Set 10 | tabialan
# City not found. Skipping...
# Processing Record 11 of Set 10 | eirunepe
# Processing Record 12 of Set 10 | guerrero negro
# Processing Record 13 of Set 10 | filingue
# Processing Record 14 of Set 10 | kondinskoye
# Processing Record 15 of Set 10 | cedar city
# Processing Record 16 of Set 10 | tarija
# Processing Record 17 of Set 10 | vestmanna
# Processing Record 18 of Set 10 | amahai
# Processing Record 19 of Set 10 | sandwick
# Processing Record 20 of Set 10 | bodden town
# Processing Record 21 of Set 10 | metallostroy
# Processing Record 22 of Set 10 | kintinku
# Processing Record 23 of Set 10 | bandundu
# Processing Record 24 of Set 10 | harper
# Processing Record 25 of Set 10 | areosa
# Processing Record 26 of Set 10 | camacha
# Processing Record 27 of Set 10 | narsaq
# Processing Record 28 of Set 10 | svetlyy
# Processing Record 29 of Set 10 | arys
# Processing Record 30 of Set 10 | ossora
# Processing Record 31 of Set 10 | marzuq
# Processing Record 32 of Set 10 | kerema
# Processing Record 33 of Set 10 | akyab
# Processing Record 34 of Set 10 | verkhnyaya toyma
# Processing Record 35 of Set 10 | shaartuz
# City not found. Skipping...
# Processing Record 36 of Set 10 | alta floresta
# Processing Record 37 of Set 10 | arman
# Processing Record 38 of Set 10 | ust-ishim
# Processing Record 39 of Set 10 | calvinia
# Processing Record 40 of Set 10 | parambu
# Processing Record 41 of Set 10 | comodoro rivadavia
# Processing Record 42 of Set 10 | nemuro
# Processing Record 43 of Set 10 | ariquemes
# Processing Record 44 of Set 10 | belmonte
# Processing Record 45 of Set 10 | muli
# Processing Record 46 of Set 10 | nizhniy kuranakh
# Processing Record 47 of Set 10 | fort william
# Processing Record 48 of Set 10 | parana
# Processing Record 49 of Set 10 | lakes entrance
# Processing Record 50 of Set 10 | hami
# Processing Record 1 of Set 11 | lata
# Processing Record 2 of Set 11 | punta de bombon
# Processing Record 3 of Set 11 | palmer
# Processing Record 4 of Set 11 | talara
# Processing Record 5 of Set 11 | esmeraldas
# Processing Record 6 of Set 11 | klyuchi
# Processing Record 7 of Set 11 | yermakovskoye
# Processing Record 8 of Set 11 | mahenge
# Processing Record 9 of Set 11 | husavik
# Processing Record 10 of Set 11 | katha
# City not found. Skipping...
# Processing Record 11 of Set 11 | pangkalanbuun
# Processing Record 12 of Set 11 | neftcala
# Processing Record 13 of Set 11 | jiaohe
# Processing Record 14 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 15 of Set 11 | el cope
# Processing Record 16 of Set 11 | ilam
# Processing Record 17 of Set 11 | tilichiki
# Processing Record 18 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 19 of Set 11 | saint-paul
# Processing Record 20 of Set 11 | forestville
# Processing Record 21 of Set 11 | vilcun
# Processing Record 22 of Set 11 | palauig
# Processing Record 23 of Set 11 | dawlatabad
# Processing Record 24 of Set 11 | panormos
# Processing Record 25 of Set 11 | ekhabi
# Processing Record 26 of Set 11 | barcelona
# Processing Record 27 of Set 11 | cartagena
# Processing Record 28 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 29 of Set 11 | mogoditshane
# Processing Record 30 of Set 11 | kurumkan
# Processing Record 31 of Set 11 | methoni
# Processing Record 32 of Set 11 | great yarmouth
# Processing Record 33 of Set 11 | general pico
# Processing Record 34 of Set 11 | balabac
# Processing Record 35 of Set 11 | tuatapere
# Processing Record 36 of Set 11 | calbuco
# Processing Record 37 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 38 of Set 11 | emerald
# Processing Record 39 of Set 11 | tazovskiy
# Processing Record 40 of Set 11 | marovoay
# Processing Record 41 of Set 11 | hokitika
# Processing Record 42 of Set 11 | teahupoo
# Processing Record 43 of Set 11 | san pedro
# Processing Record 44 of Set 11 | shimoda
# Processing Record 45 of Set 11 | grootfontein
# Processing Record 46 of Set 11 | yantal
# Processing Record 47 of Set 11 | mount isa
# Processing Record 48 of Set 11 | diu
# Processing Record 49 of Set 11 | aleksandrov gay
# Processing Record 50 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 12 | maun
# Processing Record 2 of Set 12 | luwuk
# Processing Record 3 of Set 12 | the pas
# Processing Record 4 of Set 12 | banjar
# Processing Record 5 of Set 12 | kjollefjord
# Processing Record 6 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 7 of Set 12 | kyren
# Processing Record 8 of Set 12 | naliya
# Processing Record 9 of Set 12 | kavaratti
# Processing Record 10 of Set 12 | larsnes
# Processing Record 11 of Set 12 | basco
# Processing Record 12 of Set 12 | marsh harbour
# Processing Record 13 of Set 12 | egvekinot
# Processing Record 14 of Set 12 | wanning
# Processing Record 15 of Set 12 | kiama
# Processing Record 16 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 17 of Set 12 | trat
# Processing Record 18 of Set 12 | kimbe
# Processing Record 19 of Set 12 | mashhad
# Processing Record 20 of Set 12 | constitucion
# Processing Record 21 of Set 12 | nedjo
# Processing Record 22 of Set 12 | pakxan
# Processing Record 23 of Set 12 | novyy urengoy
# Processing Record 24 of Set 12 | buraydah
# Processing Record 25 of Set 12 | urdoma
# Processing Record 26 of Set 12 | arteaga
# Processing Record 27 of Set 12 | fernley
# Processing Record 28 of Set 12 | ilulissat
# Processing Record 29 of Set 12 | sitka
# Processing Record 30 of Set 12 | winnemucca
# Processing Record 31 of Set 12 | fortuna
# Processing Record 32 of Set 12 | hobbs
# Processing Record 33 of Set 12 | lisakovsk
# Processing Record 34 of Set 12 | hambantota
# Processing Record 35 of Set 12 | huanren
# Processing Record 36 of Set 12 | tevaitoa
# Processing Record 37 of Set 12 | afua
# Processing Record 38 of Set 12 | tessalit
# Processing Record 39 of Set 12 | rondonopolis
# Processing Record 40 of Set 12 | puerto escondido
# Processing Record 41 of Set 12 | riyadh
# Processing Record 42 of Set 12 | marawi
# Processing Record 43 of Set 12 | ejido hermosillo
# Processing Record 44 of Set 12 | darhan
# Processing Record 45 of Set 12 | makasar
# Processing Record 46 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 47 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 12 | vanavara
# Processing Record 49 of Set 12 | loa janan
# Processing Record 50 of Set 12 | bubaque
# Processing Record 1 of Set 13 | weihe
# Processing Record 2 of Set 13 | roma
# Processing Record 3 of Set 13 | cayenne
# Processing Record 4 of Set 13 | touros
# Processing Record 5 of Set 13 | tagusao
# Processing Record 6 of Set 13 | qax
# Processing Record 7 of Set 13 | bloemfontein
# Processing Record 8 of Set 13 | aasiaat
# Processing Record 9 of Set 13 | maniitsoq
# Processing Record 10 of Set 13 | khasan
# Processing Record 11 of Set 13 | mocuba
# Processing Record 12 of Set 13 | zhigansk
# Processing Record 13 of Set 13 | andenes
# Processing Record 14 of Set 13 | waingapu
# Processing Record 15 of Set 13 | tefe
# Processing Record 16 of Set 13 | port blair
# Processing Record 17 of Set 13 | narrabri
# Processing Record 18 of Set 13 | adrar
# Processing Record 19 of Set 13 | simbahan
# Processing Record 20 of Set 13 | beloha
# Processing Record 21 of Set 13 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 22 of Set 13 | vestmannaeyjar
# Processing Record 23 of Set 13 | altay
# Processing Record 24 of Set 13 | hachinohe
# Processing Record 25 of Set 13 | brae
# Processing Record 26 of Set 13 | sakaiminato
# Processing Record 27 of Set 13 | pangody
# Processing Record 28 of Set 13 | saurimo
# Processing Record 29 of Set 13 | toora-khem
# Processing Record 30 of Set 13 | jagatsinghapur
# Processing Record 31 of Set 13 | giyon
# Processing Record 32 of Set 13 | hammerfest
# Processing Record 33 of Set 13 | moses lake
# Processing Record 34 of Set 13 | hun
# Processing Record 35 of Set 13 | bahia honda
# Processing Record 36 of Set 13 | rebrikha
# Processing Record 37 of Set 13 | natal
# Processing Record 38 of Set 13 | victor harbor
# Processing Record 39 of Set 13 | vettavalam
# Processing Record 40 of Set 13 | maridi
# Processing Record 41 of Set 13 | fort wellington
# Processing Record 42 of Set 13 | garm
# City not found. Skipping...
# Processing Record 43 of Set 13 | kokkola
# Processing Record 44 of Set 13 | sembakung
# Processing Record 45 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 46 of Set 13 | tura
# Processing Record 47 of Set 13 | kieta
# Processing Record 48 of Set 13 | tambul
# City not found. Skipping...
# Processing Record 49 of Set 13 | geraldton
# Processing Record 50 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 14 | bambous virieux
# Processing Record 2 of Set 14 | paramonga
# Processing Record 3 of Set 14 | spirit river
# Processing Record 4 of Set 14 | abaza
# Processing Record 5 of Set 14 | crib point
# Processing Record 6 of Set 14 | umm lajj
# Processing Record 7 of Set 14 | robertsport
# Processing Record 8 of Set 14 | polyarnyy
# Processing Record 9 of Set 14 | constantine
# Processing Record 10 of Set 14 | wainwright
# Processing Record 11 of Set 14 | gambela
# Processing Record 12 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 14 | barinitas
# Processing Record 14 of Set 14 | kargil
# Processing Record 15 of Set 14 | jega
# Processing Record 16 of Set 14 | cumana
# Processing Record 17 of Set 14 | zyryanka
# Processing Record 18 of Set 14 | lodwar
# Processing Record 19 of Set 14 | plainview
# Processing Record 20 of Set 14 | ordzhonikidze
# Processing Record 21 of Set 14 | upington
# Processing Record 22 of Set 14 | dunedin
# Processing Record 23 of Set 14 | kumylzhenskaya
# Processing Record 24 of Set 14 | santa cruz
# Processing Record 25 of Set 14 | trzebiatow
# Processing Record 26 of Set 14 | ciudad bolivar
# Processing Record 27 of Set 14 | skjervoy
# Processing Record 28 of Set 14 | rocha
# Processing Record 29 of Set 14 | roald
# Processing Record 30 of Set 14 | champerico
# Processing Record 31 of Set 14 | praia
# Processing Record 32 of Set 14 | santander
# Processing Record 33 of Set 14 | la ronge
# Processing Record 34 of Set 14 | lagunas
# Processing Record 35 of Set 14 | buenaventura
# Processing Record 36 of Set 14 | malindi
# Processing Record 37 of Set 14 | opobo
# City not found. Skipping...
# Processing Record 38 of Set 14 | arvika
# Processing Record 39 of Set 14 | galchino
# City not found. Skipping...
# Processing Record 40 of Set 14 | pisco
# Processing Record 41 of Set 14 | havoysund
# Processing Record 42 of Set 14 | canto do buriti
# Processing Record 43 of Set 14 | jacareacanga
# Processing Record 44 of Set 14 | krasnoselkup
# Processing Record 45 of Set 14 | quang ngai
# Processing Record 46 of Set 14 | pontianak
# Processing Record 47 of Set 14 | finschhafen
# Processing Record 48 of Set 14 | surin
# Processing Record 49 of Set 14 | taoudenni
# Processing Record 50 of Set 14 | vao
# Processing Record 1 of Set 15 | shimabara
# Processing Record 2 of Set 15 | abalak
# Processing Record 3 of Set 15 | stoyba
# City not found. Skipping...
# Processing Record 4 of Set 15 | turukhansk
# Processing Record 5 of Set 15 | varnavino
# Processing Record 6 of Set 15 | sainte-suzanne
# Processing Record 7 of Set 15 | beyla
# Processing Record 8 of Set 15 | kuruman
# Processing Record 9 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 10 of Set 15 | bairiki
# Processing Record 11 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 12 of Set 15 | pyapon
# Processing Record 13 of Set 15 | port hueneme
# Processing Record 14 of Set 15 | bereda
# Processing Record 15 of Set 15 | turbat
# Processing Record 16 of Set 15 | bardiyah
# Processing Record 17 of Set 15 | bonthe
# Processing Record 18 of Set 15 | chumikan
# Processing Record 19 of Set 15 | maloyaroslavets
# Processing Record 20 of Set 15 | yumen
# Processing Record 21 of Set 15 | kamina
# Processing Record 22 of Set 15 | bolshaya sosnova
# Processing Record 23 of Set 15 | manokwari
# Processing Record 24 of Set 15 | makurdi
# Processing Record 25 of Set 15 | richards bay
# Processing Record 26 of Set 15 | linjiang
# Processing Record 27 of Set 15 | hualmay
# Processing Record 28 of Set 15 | san cristobal
# Processing Record 29 of Set 15 | newport
# Processing Record 30 of Set 15 | valley city
# Processing Record 31 of Set 15 | whitehorse
# Processing Record 32 of Set 15 | brownsville
# Processing Record 33 of Set 15 | cambui
# Processing Record 34 of Set 15 | fairbanks
# Processing Record 35 of Set 15 | mnogovershinnyy
# Processing Record 36 of Set 15 | krasnogvardeyskiy
# Processing Record 37 of Set 15 | taywarah
# Processing Record 38 of Set 15 | sanhsia
# City not found. Skipping...
# Processing Record 39 of Set 15 | shiraoi
# Processing Record 40 of Set 15 | yangjiang
# Processing Record 41 of Set 15 | olavarria
# Processing Record 42 of Set 15 | zhuhai
# Processing Record 43 of Set 15 | mzimba
# Processing Record 44 of Set 15 | tocopilla
# Processing Record 45 of Set 15 | urubicha
# Processing Record 46 of Set 15 | iquique
# Processing Record 47 of Set 15 | poco das trincheiras
# Processing Record 48 of Set 15 | mitu
# Processing Record 49 of Set 15 | serabu
# Processing Record 50 of Set 15 | qandala
# Processing Record 1 of Set 16 | lyngseidet
# Processing Record 2 of Set 16 | semut
# Processing Record 3 of Set 16 | bathsheba
# Processing Record 4 of Set 16 | coahuayana
# Processing Record 5 of Set 16 | alvorada
# Processing Record 6 of Set 16 | mozarlandia
# Processing Record 7 of Set 16 | chernyshevskiy
# Processing Record 8 of Set 16 | bambanglipuro
# Processing Record 9 of Set 16 | ritchie
# Processing Record 10 of Set 16 | beyneu
# Processing Record 11 of Set 16 | gilazi
# City not found. Skipping...
# Processing Record 12 of Set 16 | abeche
# Processing Record 13 of Set 16 | dong xoai
# Processing Record 14 of Set 16 | mizdah
# Processing Record 15 of Set 16 | kununurra
# Processing Record 16 of Set 16 | oskarshamn
# Processing Record 17 of Set 16 | powell river
# Processing Record 18 of Set 16 | eyrarbakki
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Yar-Sale      RU  66.8333   70.8333     15.04        86         100
# 1          Lebu      CL -37.6167  -73.6500     52.25        91          21
# 2        Namtsy      RU  62.7161  129.6658     33.21        80         100
# 3       Kashary      RU  49.0400   41.0056     53.94        68         100
# 4      Progreso      MX  21.2833  -89.6667     82.11        80           0
# 5          Biak      ID  -0.9131  122.8766     83.35        66         100
# 6       Ushuaia      AR -54.8000  -68.3000     44.26        93         100
# 7        Talaya      RU  61.3833  152.7500     16.11        71         100
# 8        Albany      US  42.6001  -73.9662     39.58        62           7
# 9  Punta Arenas      CL -53.1500  -70.9167     42.91        81          75
#
#    Wind Speed      Description
# 0        8.77  overcast clouds
# 1        7.14       few clouds
# 2       13.15  overcast clouds
# 3        9.33  overcast clouds
# 4       15.12        clear sky
# 5        1.86  overcast clouds
# 6        9.22  overcast clouds
# 7        0.94  overcast clouds
# 8        1.01        clear sky
# 9        5.75    broken clouds

# %%
output = "WeatherPy_Database.csv"
city_data_df.to_csv(output, index_label="City_Name")
